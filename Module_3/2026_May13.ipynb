# %% [markdown]
# ### **Day 3: Decorators, Creational and Structural Patterns**
#
# #### **Module 5: A Brief Refresher on Decorators**
# * An overview on scoping rules (LEG-B)
# * Nested functions and Enclosing/External scope
# * How decorators work
# * Creating decorators using functions
# * Decorator chaining and Parameterized decorators
# * Using classes for implementing decorators
# * Best practices in creating decorators
#
# #### **Module 6: Creational Design Patterns (contd)**
# * **Abstract Factory Pattern**
# * **Builder Pattern**
# * **Prototype Pattern**
#
# #### **Module 7: Interface & Composition Patterns**
#
# * **Adapter:** Wrapping legacy code/libraries (Duck typing vs. ABCs).
# * **Facade:** Simplifying complex internal subsystems for external consumers.
# * **Bridge:** Decoupling abstraction from implementation (Composition over Inheritance).
#
# #### **Module 8: Performance & Proxy Patterns**
#
# * **Proxy:** Lazy initialization, Remote Proxies, and Protection Proxies using `__getattr__`.
# * **Flyweight:** Using `__get__`, `__set__` and Factory pools to manage massive object counts.
# * **Composite:** Handling recursive tree structures (filesystems, GUI hierarchies).

# %% [markdown]
# ---
